# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import csv

# %%
import re

# %%
states= pd.read_csv('/Users/malcolmbarnes/Desktop/USDemographics.csv')
income= pd.read_csv('/Users/malcolmbarnes/Desktop/modesto.csv')
states
# Out:
#            Sex and age Number, 2000  Percent Number, 2010 Percent.1
# 0    Total population   281,421,906  100.00%  308,745,538   100.00%
# 1                 Male  138,053,563     49.1  151,781,326      49.2
# 2               Female  143,368,343     50.9  156,964,212      50.8
# 3        Under 5 years   19,175,798      6.8   20,201,362       6.5
# 4         5 to 9 years   20,549,505      7.3   20,348,657       6.6
# 5       10 to 14 years   20,528,072      7.3   20,677,194       6.7
# 6       15 to 19 years   20,219,890      7.2   22,040,343       7.1
# 7       20 to 24 years   18,964,001      6.7   21,585,999         7
# 8       25 to 34 years   39,891,724     14.2   41,063,948      13.3
# 9       35 to 44 years   45,148,527       16   41,070,606      13.3
# 10      45 to 54 years   37,677,952     13.4   45,006,716      14.6
# 11      55 to 59 years   13,469,237      4.8   19,664,805       6.4
# 12      60 to 64 years   10,805,447      3.8   16,817,924       5.4
# 13      65 to 74 years   18,390,986      6.5   21,713,429         7
# 14      75 to 84 years   12,361,180      4.4   13,061,122       4.2
# 15   85 years and over    4,239,587      1.5    5,493,433       1.8
# 16  Median age (years)         35.3     n.a.         37.2      n.a.
# 17   18 years and over  209,128,094     74.3  234,564,071        76
# 18   21 years and over  196,899,193       70  220,958,853      71.6
# 19   62 years and over   41,256,029     14.7   49,972,181      16.2
# 20   65 years and over   34,991,753     12.4   40,267,984        13

# %%
income
# Out:
#            Country United States   Ukraine Ethiopia   Average
# 0   Income/ Person      $41,678   $16, 390    $954   $19,674
# 1  Life Expectancy            79        68       63        70

# %%
states_recent= states[['Sex and age', 'Number,2010']]
states_recent
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-2c153233a620> in <module>()
# ----> 1 states_recent= states[['Sex and age', 'Number,2010']]
#       2 states_recent
#
# /Users/malcolmbarnes/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1789         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1790             # either boolean or fancy integer index
# -> 1791             return self._getitem_array(key)
#    1792         elif isinstance(key, DataFrame):
#    1793             return self._getitem_frame(key)
#
# /Users/malcolmbarnes/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    1833             return self.take(indexer, axis=0, convert=False)
#    1834         else:
# -> 1835             indexer = self.ix._convert_to_indexer(key, axis=1)
#    1836             return self.take(indexer, axis=1, convert=True)
#    1837
#
# /Users/malcolmbarnes/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1110                 mask = check == -1
#    1111                 if mask.any():
# -> 1112                     raise KeyError('%s not in index' % objarr[mask])
#    1113
#    1114                 return _values_from_object(indexer)
#
# KeyError: "['Number,2010'] not in index"

# %% [markdown]
# Here I did a simple selection of the first two rows of the states dataframe. I would like more time to work on this since I really wanted to create two seperate dfs for each year and then plot a visual illustrating them.

# %%
states[0:1]
# Out:
#          Sex and age Number, 2000  Percent Number, 2010 Percent.1
# 0  Total population   281,421,906  100.00%  308,745,538   100.00%

# %%
show= income.plot(kind=bar)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-839a936de964> in <module>()
# ----> 1 show= income.plot(kind=bar)
#
# /Users/malcolmbarnes/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2486                  yerr=yerr, xerr=xerr,
#    2487                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2488                  **kwds)
#    2489
#    2490
#
# /Users/malcolmbarnes/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2270 def _plot(data, x=None, y=None, subplots=False,
#    2271           ax=None, kind='line', **kwds):
# -> 2272     kind = _get_standard_kind(kind.lower().strip())
#    2273     if kind in _all_kinds:
#    2274         klass = _plot_klass[kind]
#
# AttributeError: 'function' object has no attribute 'lower'

# %% [markdown]
# Here I was attempting a bar chart to illustrate the differences in income/age ratio visually.
